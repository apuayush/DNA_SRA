# %%
import cv2
import numpy as np
import utils
from skimage import io as io
import matplotlib.pyplot as plt
% matplotlib inline

# %%
img = io.imread('admin_tools/imgs/img2.png')

# %%
x1, y1, x2, y2 = [122, 554, 193, 627]

# %%
roi = img[y1: y2-25, x1: x1+56]

# %%
x1,y1,x2,y2 = [240, 457, 487, 521]
roi2 = img[y1: y2, x1: x2]

# %%
plt.imshow(roi2)

# %%
## convert to hsv
hsv = cv2.cvtColor(roi2, cv2.COLOR_BGR2HSV)

## mask of green (36,0,0) ~ (70, 255,255)
mask = cv2.inRange(hsv, (150, 0, 100), (200, 20,172))

## slice the green
imask = mask>0
green = np.zeros_like(roi2, np.uint8)

# %%
plt.imshow(green)
